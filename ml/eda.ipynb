# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df = pd.read_csv('final_df.csv')

# %% [markdown]
# # EDA

# %%
df
# Out:
#        season  round  weather_warm  weather_cold  weather_dry  weather_wet  \
# 0        1983      1         False         False         True        False
# 1        1983      1         False         False         True        False
# 2        1983      1         False         False         True        False
# 3        1983      1         False         False         True        False
# 4        1983      1         False         False         True        False
# ...       ...    ...           ...           ...          ...          ...
# 15317    2022     22          True         False        False        False
# 15318    2022     22          True         False        False        False
# 15319    2022     22          True         False        False        False
# 15320    2022     22          True         False        False        False
# 15321    2022     22          True         False        False        False
#
#        weather_cloudy           driver  grid  podium  ...  \
# ...

# %%
len(df[df['podium'] == 1])
# Out:
# 699

# %%
corrM = df.corr()
corrM
# Out:
#                           season     round  weather_warm  weather_cold  \
# season                  1.000000  0.157216     -0.054139     -0.137880
# round                   0.157216  1.000000      0.026375     -0.018764
# weather_warm           -0.054139  0.026375      1.000000     -0.093917
# weather_cold           -0.137880 -0.018764     -0.093917      1.000000
# weather_dry            -0.227454 -0.041466     -0.284822     -0.075812
# ...                          ...       ...           ...           ...
# constructor_team_lotus -0.185177 -0.024162      0.020219      0.022158
# constructor_toro_rosso  0.164409  0.024918     -0.011557     -0.021803
# constructor_toyota      0.036498  0.000791      0.012826     -0.012516
# constructor_tyrrell    -0.175085 -0.031986      0.015752      0.031942
# constructor_williams    0.025330  0.002832     -0.002891     -0.004251
#
#                         weather_dry  weather_wet  weather_cloudy      grid  \
# ...

# %%
plt.matshow(df.corr())
plt.show()

# %%
ranking_correlation = df.corrwith(df["podium"])
ranking_correlation.sort_values(inplace=True)
ranking_correlation
# Out:
# driver_points               -0.329672
# constructor_points          -0.324248
# constructor_wins            -0.320096
# driver_wins                 -0.290782
# constructor_ferrari         -0.181671
#                                ...
# nationality_Italian          0.143244
# driver_standings_pos         0.351320
# constructor_standings_pos    0.398702
# grid                         0.482930
# podium                       1.000000
# Length: 100, dtype: float64

# %%
ranking_plot = ranking_correlation.plot.bar(x='Features', y='R^2', figsize=(20, 5), color='green')

# %%
ranking_plot = ranking_correlation.plot.bar(x='Features', y='R^2', figsize=(20, 5), color='green')

# %%
ranking_plot.figure.tight_layout() 
ranking_plot.figure.set_facecolor('white')
ranking_plot.figure.savefig('correlation_podium.png', transparent=False)
# plt.show()

# %%
driver_points_podium = df[['driver_points', 'podium']]

# %%
plt.scatter(driver_points_podium['podium'], driver_points_podium['driver_points'])
